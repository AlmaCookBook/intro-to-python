# %% [markdown]
# <img src="graphics/icr_logo.png" alt="drawing" width="300"/>
#
# # An introduction to programming with Python
#
# ## Outline for self-study
#
# Work through each of these notebooks in order, checking the solutions  in the solutions directory as you go. If you have any questions you can contact scsoftware.icr.ac.uk or try the python-training slack group in Scientific Computing Services. It is intended that the material might take roughly 2 days. The first day is mostly acquiring concepts and the second day is mostly practice.
#
# ## Outline for in-person 2 day course
#
# The in-person (or online) courses take the form of a guided workshop. There is an element of micro-flipped-learning: we go through each module first individually / talking to colleagues / asking for guidance, before coming back together as a group and looking for the solution by consensus.
#
# #### In person
#
# For in person sessions the exercise time is a time for you to talk to each other, ask questions, have a walk, a break, get a coffee...
#
# #### Online
#
# When online, the exercise time will be quiet time, and then when we come back as a group I will give space for asking questions and sharing answers. There are breakout rooms available either for 1:1 help in the quiet times, or for working with a colleague if you wish. Teams doesn't allow you to move yourself so if you would like to do this I will move you in at the start of the quiet times. Otherwise I will leave the main room quiet with the reconvene time showing. Take a break during these quiet times when you need it.
#
# ### Day 1
#
# - **A-00** Preamble, explain how this course is going to work
#
# - **A-01** Python language syntax
#
# - **A-02** Variables and data types
#
# - **A-03** Basic operations
#
# - **A-04** Containers
#
# - **A-05** Conditional statements
#
# - **A-06** Loops
#
# ***
#
# ### Day 2
#
# - **B-01** Dictionaries
#
# - **B-02** More loops
#
# - **B-03** Codon permutations - practice exercise
#
# - **B-04** DNA analysis - practice exercise
#
# - **B-05** Patient records - practice exercise
#
# - **B-06** Fibonacci numbers - practice exercise
#
# - **B-07** Functions
#
# - **B-08** Libraries
#
# - **B-09** File IO
#
# - **B-10** Dataframes
#
# For the in person training some post course study is anticipated to consolidate the material and complete anything missed.
